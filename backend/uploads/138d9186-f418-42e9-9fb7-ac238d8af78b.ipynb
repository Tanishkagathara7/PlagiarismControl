# %%
import matplotlib.pyplot as pltimport seaborn as snsdef create_plot(x, y):    plt.figure(figsize=(10, 6))    plt.plot(x, y)    plt.title("Sample Plot")    plt.show()x_values = range(10)y_values = [i**2 for i in x_values]create_plot(x_values, y_values)
