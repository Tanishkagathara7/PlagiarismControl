# %%
import pandas as pdimport numpy as npdef calc_average(numbers):    return sum(numbers) / len(numbers)def process_dataframe(dataframe):    dataframe['average'] = dataframe.apply(calc_average, axis=1)    return dataframevalues = [1, 2, 3, 4, 5]avg = calc_average(values)print(f"Average: {avg}")
