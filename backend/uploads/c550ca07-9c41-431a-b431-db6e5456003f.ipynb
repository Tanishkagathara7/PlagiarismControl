# %%
import pandas as pdimport numpy as npdef calculate_mean(data):    return sum(data) / len(data)def process_data(df):    df['mean'] = df.apply(calculate_mean, axis=1)    return dfdata = [1, 2, 3, 4, 5]result = calculate_mean(data)print(f"Mean: {result}")
